# %%
import pandas as pd

df = pd.read_csv('../../data/plot_data/TSNE_transformer_2022-11-03.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x='x', y='y', hue='url', legend=False)
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>
